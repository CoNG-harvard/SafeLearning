# %%
import numpy as np
import cvxpy as cp
from matplotlib import pyplot as plt

from time import time
from functools import partial

import sys
sys.path.append('../../')

from Environment import SpringMass
from Subroutines import ModelEstV2,ApproxDAP,max_norm,find_stable_radius,SafeTransit,spectral_radius
from time import time
from Controllers import SafeDAP
from scipy.linalg import sqrtm
import pickle as pkl
# %load_ext autoreload
# %autoreload 2

# %%
class TimeStepsReached(Exception):
    pass
def evaluate(space_dim,dt,K_m_dt,l_m_dt):
    O = np.zeros((space_dim,space_dim))
    I = np.eye(space_dim)

    A = np.vstack([np.hstack([O,dt*I]),
                   np.hstack([-K_m_dt*I,-l_m_dt*I])]) + np.eye(2*space_dim)

    return  np.max(np.abs(np.linalg.eigvals(A)))

# %% [markdown]
# # Set up the system

# %% [markdown]
# ## Find a loosely stable spring-mass system

# %%
H_benchmark = 80
eps = 0.1

rho_target = eps**(1/H_benchmark)

# %%
rho_target
# Out:
# 0.9716279515771061

# %%
w_max = 0.5


dt = 0.1
space_dim = 1
m = 1

candidate_param = np.random.rand(1000,2) * 0.06
istar = np.argmin([evaluate(space_dim,dt,K_m_dt,l_m_dt) for (K_m_dt,l_m_dt) in candidate_param])

K_star, l_star = candidate_param[istar]


K_star,l_star

K = K_star * m/dt

l = l_star*m/dt

print('Spectral radius of A:',evaluate(space_dim,dt,K_star,l_star),K,l)

x_0 = np.array([0,0]).reshape(-1,1)
time_steps = 200

env = SpringMass(x_0 = x_0,m=m,K_stab = K,l=l,w_adv_fraction=0,w_max=w_max)


x_rand_disturbance = []
# main loop
for _ in range(time_steps):
    x = env.state()
    u = 0 
        
    env.step(u)
    
    
    x_rand_disturbance.append(x)
    
    if _%100 == 0:
        print('Step',_)


# plt.plot(np.array(x_hist)[:,0],label='SafeDAP')
plt.figure(dpi=200)
plt.plot(np.array(x_rand_disturbance)[:,0],label=r'$w_{rand}$')
plt.xlabel('t')
plt.ylabel('x')
plt.legend()


A = env.A
B = env.B

A_pow = [np.eye(2)]
for i in range(H_benchmark):
    A_pow.append(A_pow[-1].dot(A))
            
print('rho(A_pow[-1])',spectral_radius(A_pow[-1]),'Sum(A_pow)',np.sum([np.linalg.norm(A,1) for A in A_pow]),'dx/w_max',np.max(x_rand_disturbance)/w_max)
# Out:
# Spectral radius of A: 0.9700674038702769 0.09522606703376087 0.5992149261871875
# Step 0
# Step 100
# rho(A_pow[-1]) 0.08793321176890585 Sum(A_pow) 94.71601928036883 dx/w_max 16.283583448597657

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Experiment parameters

# %%
### Find a region(B(A,eps_init)) around A and ensure it contains only stable matrices.
eps_init = find_stable_radius(A)

est = ModelEstV2(A,B,eps_init) # The model estimator.
# est = ModelEstV3() # The model estimator.

H = 20# Look back length



# Constants
x_dim = A.shape[-1]
u_dim = B.shape[-1]

I_x = np.eye(x_dim)  
I_u = np.eye(u_dim)  


w_cov = np.eye(x_dim) * env.w_max * 1/12 # Assume uniform distribution.

# Optimaization Problem Parameters

Q = np.array([[1,0],
                [0,1]])*1
R = np.eye(u_dim)*1

D_x = np.vstack([I_x,-I_x]) # Constraints4
d_x = np.array([6.0,40.0,6.0,40.0])

D_u = np.vstack([I_u,-I_u])
d_u = np.array([100.0,100.0])


M0 = np.zeros((H,u_dim,x_dim))

e_x = 0 # Usually e_x is not zero 
e_u = 0 # For safe DAP with known B, e_u = 0

refit_per_step = 50
pre_run_steps = 2
TD_steps  = 30 # The least number of steps taken in Phase 1.

eta_bars = [0.1,0.5,1.0,1.5,2.0]
# eta_bars = [0.1]

# eta_bars = [0.1]

params = {'Q':Q,'R':R,'D_x':D_x,'d_x':d_x,'D_u':D_u,'d_u':d_u,'A':A,'B':B,'H':H,'H_benchmark':H_benchmark,'eta_bars':eta_bars,'w_max':w_max}
with open('./data/Parameters.pkl','wb') as f:
    pkl.dump(params,f)

# %%
def PlainSim(timesteps,n_trials):
    
    def main_loop():
        env = SpringMass(x_0 = x_0,m=m,K_stab = K,l=l,w_adv_fraction=0,w_max = w_max)

        x_no_control_hist = []
        # main loop
        for _ in range(timesteps):
            x = env.state()
            u = 0 
            env.step(u)

            x_no_control_hist.append(x)

            if _%100 == 0:
                print('Step',_)

        data = {}
        data['x'] = x_no_control_hist
        return data
    
    trial_data = []
    _ = 0 
    while _ < n_trials: 
        t = time()
        print('Trial {}'.format(_))
        trial_data.append(main_loop())
        _+=1

        print('Time for trial:',time()-t)
    return trial_data

def BenchmarkSim(timesteps,n_trials,unconstrained=False):

    def main_loop(M):
        # Reset the environment
        env = SpringMass(x_0 = x_0,m=m,K_stab = K,l=l,w_adv_fraction=0,w_max = w_max)

        x_true_hist = []
        u_true_hist = []
        w_true_hist = [np.zeros((x_dim,1)) for _ in range(10*H_benchmark)]

        # main loop 
        for _ in range(timesteps):
            x = env.state()
            x_true_hist.append(x)
            if _<pre_run_steps:
                u = (np.random.rand()-0.5)*2*0
            else:
                u = ApproxDAP(M,w_true_hist,0)

            env.step(u)
            u_true_hist.append(u)

            w_true_hist.append(env.state()-A.dot(x_true_hist[-1])-B.dot(u_true_hist[-1]))

            if _%100 == 0:
                print('Step',_)

        # Prepare data output
        data = {}
        data['x'] = x_true_hist
        data['u'] = u_true_hist
        data['w'] = w_true_hist
        
#         print(data['w'])
        return data



    safeDapSolver = SafeDAP(Q,R,D_x,d_x,D_u,d_u,w_max,w_cov)

    if unconstrained:
        M,Phi = safeDapSolver.solve(A,B,H_benchmark,e_x=e_x,e_u=e_u,unconstrained=True)
    else:
        M,Phi = safeDapSolver.solve(A,B,H_benchmark,e_x=e_x,e_u=e_u)
    
#     print('M',M)

    trial_data = []
    _ = 0 
    while _ < n_trials: 

        print('Trial {}'.format(_))
        trial_data.append(main_loop(M))
        _+=1
        
    return trial_data

# %%
n_trials = 10
timesteps = 400

alg_dict = {
    'Plain':PlainSim,
            'UnconstrainedDAP':partial(BenchmarkSim,unconstrained=True),
            'ConstrainedDAP':partial(BenchmarkSim,unconstrained=False)
           }


for key, alg in alg_dict.items():
    print("{} starts.".format(key))
    
    t = time()
      

    trial_data = alg(timesteps,n_trials)
    with open('./data/{}.pkl'.format(key),'wb') as f:
        pkl.dump(trial_data,f)
    
    print('Total Time for {}:'.format(key),time()-t)
# Out:
# Plain starts.
# Trial 0
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.010880470275878906
# Trial 1
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.009000062942504883
# Trial 2
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.008242607116699219
# Trial 3
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.010325193405151367
# Trial 4
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.008541584014892578
# Trial 5
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.008866310119628906
# Trial 6
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.009522676467895508
# Trial 7
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.015709638595581055
# Trial 8
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.012237787246704102
# Trial 9
# Step 0
# Step 100
# Step 200
# Step 300
# Time for trial: 0.010380983352661133
# Total Time for Plain: 0.12871074676513672
# UnconstrainedDAP starts.
# Trial 0
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 1
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 2
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 3
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 4
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 5
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 6
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 7
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 8
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 9
# Step 0
# Step 100
# Step 200
# Step 300
# Total Time for UnconstrainedDAP: 5.937932968139648
# ConstrainedDAP starts.
# Trial 0
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 1
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 2
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 3
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 4
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 5
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 6
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 7
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 8
# Step 0
# Step 100
# Step 200
# Step 300
# Trial 9
# Step 0
# Step 100
# Step 200
# Step 300
# Total Time for ConstrainedDAP: 16.681336402893066

# %%
for eta_bar in eta_bars:

    def SafeAdaptiveSim(timesteps,unconstrained=False):
        # Data containers

        x_hist = []
        u_hist = []
        w_hat_hist = [np.zeros((x_dim,1)) for _ in range(10*H)]

        theta_hist = []
        refit_time_step = []
        phase1_endpoints =[]
        phase2_endpoints=[]
        M_hist = [M0]
        r_hist = []

        n_episode = 0

        def phase(A_hat,B_hat,old_eta,new_eta):
            # Local variables: A_hat,B_hat,old,new.
            # Global variables: theta_hist,M_hist,e_x,e_u,H,env,w_max, w_hat_hist
            # Start of the phase
            # Solve for new controller M.
            if unconstrained:
                M,Phi = safeDapSolver.solve(A_hat,B_hat,H,e_x=e_x,e_u=e_u,unconstrained=True)
            else:
                M,Phi = safeDapSolver.solve(A_hat,B_hat,H,e_x=e_x,e_u=e_u)

            if n_episode==1:
                 old = {'M':np.array(M),'theta':(np.array(A_hat),np.array(B_hat)),'eta':old_eta,'r':r_hist[-1]}
            else:
                old = {'M':np.array(M_hist[-1]),'theta':theta_hist[-2],'eta':old_eta,'r':r_hist[-2]}
            new = {'M':np.array(M),'theta':theta_hist[-1],'eta':new_eta,'r':r_hist[-1]}

            old['e_x']=new['e_x']=e_x
            old['e_u']=new['e_u']=e_u

            M_hist.append(np.array(M))

            # Compute mid.
            mid = safeDapSolver.mid(old,new,H)

            transit = SafeTransit(old,new,mid,H)

            for i in range(refit_per_step):
                x = env.state()
                u = transit.get_u(w_hat_hist)
                env.step(u)

                Ah,Bh = transit.get_theta()
                # Calculate the estimated disturbance, and project it onto the bounded disturbance set. 
                w_hat = env.state()-Ah.dot(x)-Bh.dot(u)
                w_hat[w_hat>w_max] = w_max
                w_hat[w_hat<-w_max] = -w_max 
                w_hat_hist.append(np.array(w_hat)) 

                u_hist.append(u)
                x_hist.append(x)

                if len(x_hist)>=timesteps:
                    raise TimeStepsReached # Use the exception mechanism to stop the main loop once the total timestep is reached.

                # Updating M in the transit object.
                transit.step()
            # End of the phase


        env = SpringMass(x_0 = x_0,m=m,K_stab = K,l=l,w_adv_fraction=0,w_max=w_max)

        safeDapSolver = SafeDAP(Q,R,D_x,d_x,D_u,d_u,w_max,w_cov)

        try:
        # main loop
            while True:

                if n_episode==0:
                    for i in range(pre_run_steps):
                        x = env.state()
                        x_hist.append(x)
                        u = (np.random.rand()-0.5)*2*eta_bar
                        env.step(u)
                        u_hist.append(u)
                    A_hat,B_hat,r = est.est(np.array(x_hist).reshape(-1,x_dim),np.array(u_hist[:-1]).reshape(-1,u_dim))
#                     print(A_hat,B_hat)
                    theta_hist.append((np.array(A_hat),np.array(B_hat)))
                    r_hist.append(float(r))
                    refit_time_step.append(len(x_hist))
    #                 print(A_hat,B_hat)

                    # Fit the system parameters for the first time.
                else:

                    # Phase 1: exploration exploitation 

#                     print('phase 1')
                    phase(A_hat,B_hat,0,eta_bar)

                    phase1_endpoints.append(len(x_hist))

                    # Refit the system model
                    A_hat,B_hat,r = est.est(np.array(x_hist).reshape(-1,x_dim),np.array(u_hist[:-1]).reshape(-1,u_dim))
#                     print(A_hat,B_hat)
                    theta_hist.append((np.array(A_hat),np.array(B_hat)))
                    r_hist.append(float(r))
                    refit_time_step.append(len(x_hist))

                    # Phase 2: pure exploitation 
#                     print('phase 2')
                    phase(A_hat,B_hat,eta_bar,0)

                    phase2_endpoints.append(len(x_hist))


                    print('Episode',n_episode)

                n_episode+=1

        except TimeStepsReached:
            print('Time Steps Reached')
            # Prepare data output


        # Prepare data output
        data = {}
        data['x'] = x_hist
        data['u'] = u_hist
        data['w'] = w_hat_hist
        return data
    
    alg_dict = {'SafeLearning':partial(SafeAdaptiveSim,unconstrained=False),
               'UnconstrainedLearning':partial(SafeAdaptiveSim,unconstrained=True)
               }


    n_trials = 10
    time_steps = 400
    for key, alg in alg_dict.items():
        print("{} starts.".format(key))
        trial_data = []
        _ = 0 
        while _ < n_trials: 
            t = time()
            try:
                print('Trial {}'.format(_))
                trial_data.append(alg(time_steps))
                _+=1
            except AttributeError:
                print('Infeasibility Encountered. Restarting the loop.')
            except cp.SolverError:
                print('Solver Error Encountered. Restarting the loop.')
            
            print('Time for trial:',time()-t)
            
        with open('./data/{}_eta_{}.pkl'.format(key,eta_bar),'wb') as f:
            pkl.dump(trial_data,f)

from IPython.display import Audio

sound_file = '../../sound/Bike-bell-sound.wav'
Audio(sound_file,autoplay=True)
# Out:
# SafeLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 21.229880809783936
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 5.352885484695435
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.736666202545166
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.805681467056274
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 25.86168622970581
# Trial 1
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 12.485964059829712
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 25.865207195281982
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.1907477378845215
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 23.61077332496643
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 25.947360277175903
# Trial 4
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 12.312121152877808
# Trial 4
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 12.2191801071167
# Trial 4
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 18.55217981338501
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.258853435516357
# Trial 4
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 12.364983081817627
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 28.950023889541626
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 5.306701421737671
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 30.996668338775635
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.870095491409302
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.845117568969727
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 25.260932683944702
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 23.432692050933838
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 3.8801510334014893
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 3.9515490531921387
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.172981023788452
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 4.2128050327301025
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 26.9164080619812
# Trial 9
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.268078565597534
# Trial 9
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 9.77301287651062
# Trial 9
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7344017028808594
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.771041870117188
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.793302297592163
# UnconstrainedLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.462613344192505
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.289419412612915
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.157867431640625
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.206750392913818
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.102235794067383
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.330180168151855
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.102591037750244
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.10340666770935
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.224517583847046
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.171408891677856
# SafeLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 16.097028970718384
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7944092750549316
# Trial 1
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.87284803390503
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.831777811050415
# Trial 1
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.914932250976562
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.829423189163208
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.686985731124878
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.908158302307129
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 8.001810550689697
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.9188551902771
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.733389377593994
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.925299167633057
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7548389434814453
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.981054067611694
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.751197099685669
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.801046371459961
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.884870767593384
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.801161766052246
# Trial 3
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.945864915847778
# Trial 3
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.865334749221802
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.693779468536377
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.733853101730347
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.781936168670654
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.789879083633423
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.805522441864014
# Trial 6
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.988080739974976
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.787111282348633
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.8294360637664795
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.835964679718018
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7710211277008057
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.757550239562988
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.805114984512329
# Trial 8
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.863407850265503
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.875976800918579
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.712125778198242
# UnconstrainedLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.360800743103027
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.248387575149536
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.26981496810913
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.111926317214966
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.098122835159302
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.048245668411255
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.113261938095093
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.06757402420044
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.117719888687134
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.132663011550903
# SafeLearning starts.
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.88935923576355
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.856400489807129
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.93300199508667
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.908840894699097
# Trial 1
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.938241004943848
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7950282096862793
# Trial 1
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.958617925643921
# Trial 1
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.942825555801392
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7270655632019043
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.780306577682495
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7210733890533447
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.801360368728638
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7365410327911377
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.802049398422241
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.681671142578125
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.727539777755737
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.779629707336426
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7480273246765137
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7057156562805176
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.789332389831543
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7507665157318115
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.83608365058899
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7318460941314697
# Trial 4
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.848447561264038
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.75556230545044
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.630512475967407
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.760941743850708
# Trial 5
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.898424863815308
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.741913318634033
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.64713191986084
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7811334133148193
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.753276109695435
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.816622018814087
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.769273042678833
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.857278108596802
# Trial 7
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.810633420944214
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.823002576828003
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.79551362991333
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.728060245513916
# Trial 9
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.8200314044952393
# Trial 9
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.904611110687256
# Trial 9
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.771873235702515
# Trial 9
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.938642501831055
# Trial 9
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.738995313644409
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.750338792800903
# UnconstrainedLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.478573560714722
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.299919605255127
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.182472944259644
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.08606243133545
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.027703046798706
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.077630519866943
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.044665575027466
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.112308025360107
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.188984632492065
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.124328374862671
# SafeLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 16.057195901870728
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.826719999313354
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.866811990737915
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.793178081512451
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.767613410949707
# Trial 2
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.842883348464966
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7279574871063232
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7352633476257324
# Trial 2
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7353861331939697
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.726475477218628
# Trial 3
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.966754913330078
# Trial 3
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.922863960266113
# Trial 3
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.854398727416992
# Trial 3
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.68867802619934
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.797157049179077
# Trial 3
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7542781829833984
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.668651103973389
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.772637128829956
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7252018451690674
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.561845302581787
# Trial 5
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.901014804840088
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.694770336151123
# Trial 5
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.8927717208862305
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.745295524597168
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.748572826385498
# Trial 5
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.896831274032593
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.69811749458313
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.756681203842163
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.644295454025269
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7926313877105713
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.739098310470581
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.612956285476685
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.621720790863037
# Trial 8
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.894503116607666
# Trial 8
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.874290704727173
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7222561836242676
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.746129274368286
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7242701053619385
# Trial 8
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.788271427154541
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.80696702003479
# Trial 8
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.81371021270752
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.8064963817596436
# Trial 8
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.740368366241455
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.62933874130249
# Trial 9
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.77278733253479
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.575206279754639
# UnconstrainedLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.390292644500732
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.08608078956604
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.210492134094238
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.070943117141724
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.039990663528442
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 11.990089416503906
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.048642873764038
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.002143859863281
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.0420823097229
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.059455156326294
# SafeLearning starts.
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.9054360389709473
# Trial 0
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.8067612648010254
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.78340744972229
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.780536413192749
# Trial 1
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7346489429473877
# Trial 1
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 8.016473531723022
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.671672105789185
# Trial 2
# Episode 1
# Solver Error Encountered. Restarting the loop.
# Time for trial: 7.925295829772949
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.521435022354126
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.795179843902588
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.8039705753326416
# Trial 4
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.9066743850708
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7271313667297363
# Trial 4
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.729771137237549
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.707548141479492
# Trial 5
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7105486392974854
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.682618379592896
# Trial 6
# Episode 1
# Episode 2
# Solver Error Encountered. Restarting the loop.
# Time for trial: 11.813623666763306
# Trial 6
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.8273494243621826
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.640264987945557
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7492589950561523
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7265615463256836
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7109310626983643
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7523069381713867
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Solver Error Encountered. Restarting the loop.
# Time for trial: 15.513891696929932
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.761101007461548
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.725229024887085
# Trial 7
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7082581520080566
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.657657623291016
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.658843994140625
# Trial 9
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7865612506866455
# Trial 9
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 2.7290561199188232
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 15.583655834197998
# UnconstrainedLearning starts.
# Trial 0
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.403938293457031
# Trial 1
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.177725553512573
# Trial 2
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.095529556274414
# Trial 3
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.101263284683228
# Trial 4
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 11.987005949020386
# Trial 5
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.07698130607605
# Trial 6
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.010074615478516
# Trial 7
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.002334117889404
# Trial 8
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 11.94815182685852
# Trial 9
# Episode 1
# Episode 2
# Episode 3
# Time Steps Reached
# Time for trial: 12.089815616607666
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
