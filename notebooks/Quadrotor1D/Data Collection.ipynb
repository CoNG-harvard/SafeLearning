# %%
import numpy as np
import cvxpy as cp
from matplotlib import pyplot as plt

from time import time
from functools import partial

import sys
sys.path.append('../../')

from Environment import Quadrotor1D
from Subroutines import QuadrotorEst,ApproxDAP,max_norm,find_stable_radius,SafeTransit,spectral_radius
from time import time
from Controllers import SafeDAP
from scipy.linalg import sqrtm
import pickle as pkl
# %load_ext autoreload
# %autoreload 2

# %%
class TimeStepsReached(Exception):
    pass
def evaluate(space_dim,dt,K_m_dt,l_m_dt):
    O = np.zeros((space_dim,space_dim))
    I = np.eye(space_dim)

    A = np.vstack([np.hstack([O,dt*I]),
                   np.hstack([-K_m_dt*I,-l_m_dt*I])]) + np.eye(2*space_dim)

    return  np.max(np.abs(np.linalg.eigvals(A)))

# %% [markdown]
# # Set up the system

# %%
A_hat_0 = np.array([[1,1.],[0,0.6]]) 
B_hat_0 = np.array([[0],[0.9]])
r_0 = 0.2

# %%
m = 1
K_stab = np.array([[2/3,1]])



l = 0.25
dt = 1
w_max = 0.2

env=Quadrotor1D(m,K_stab,l,w_max,dt)

# %% [markdown]
# # $\Theta_{ini}$

# %%
alpha_limit = (0.5,1.2)
beta_limit = (0.2,0.4)

# %% [markdown]
# # Optimization Parameters

# %%
# Constants
x_dim = env.AK.shape[-1]
u_dim = env.B.shape[-1]


I_x = np.eye(x_dim)  
I_u = np.eye(u_dim)  

w_cov = np.eye(x_dim) * env.w_max**2 # Assume uniform distribution.

# Cost matrices

Q = np.array([[1,0],
                [0,1]])*1
R = np.eye(u_dim)*1

# Constraints

x_max = 5.0
x_min = -1

v_max = 2
v_min = -2

u_max = 5
u_min = -9.8

D_x = np.vstack([I_x,-I_x]) # Constraints
d_x = np.array([x_max,v_max,-x_min,-v_min])

D_u = np.vstack([I_u,-I_u])
d_u = np.array([u_max,-u_min])

# Lookback lengths
H=6
H_benchmark = 6

M0 = np.zeros((H,u_dim,x_dim))

e_x_0 = 1.0 # Usually e_x is not zero 
e_u_0 = 0.3 # For safe DAP with known B, e_u = 0
decay = 0.7

refit_per_step = 50
pre_run_steps = 10
TD_steps  = 30 # The least number of steps taken in Phase 1.

eta_bars = [0.1,0.2,0.5,1.0]

# %%
safeDapSolver = SafeDAP(Q,R,D_x,d_x,D_u,d_u,w_max,w_cov)
     
b_target_0 = 0.0
b_target = safeDapSolver.solve_b_star(b_target_0,env.A,env.B,e_x_0,e_u_0,H,K_stab)[0]
### b_target should not exceed solve_b_star()'s value for the subsequent optimization problem to be feasible. ###

# %% [markdown]
# # Save a copy of the parameters we have

# %%
params = {'Q':Q,'R':R,'D_x':D_x,'d_x':d_x,'D_u':D_u,'d_u':d_u,\
          'w_cov':w_cov,\
          'alpha_limit':alpha_limit,'beta_limit':beta_limit,\
          'H':H,'H_benchmark':H_benchmark,'eta_bars':eta_bars,\
          'A':env.A,'AK':env.AK,'B':env.B,\
          'A_hat_0':A_hat_0,'B_hat_0':B_hat_0,'r_0':r_0,\
          'w_max':w_max,'K_stab':K_stab,'b_target':b_target,'l':l,'m':m,'dt':dt,'eta_bars':eta_bars}
with open('./data/Parameters.pkl','wb') as f:
    pkl.dump(params,f)

# %% [markdown]
# # Experiment lengths

# %%
n_trials = 20
timesteps = 500

# %% [markdown]
# # Benchmark Experiments

# %%
def PlainSim(timesteps,n_trials):
    
    def main_loop():
        env=Quadrotor1D(m,K_stab,l,w_max,dt)
        
        x_no_control_hist = []
        # main loop
        for _ in range(timesteps):
            x = env.state()
            u = 0 
            env.step(u,b_target)

            x_no_control_hist.append(x)

            if _%100 == 0:
                print('Step',_)

        data = {}
        data['x'] = x_no_control_hist
        return data
    
    trial_data = []
    _ = 0 
    while _ < n_trials: 
        t = time()
        print('Trial {}'.format(_))
        trial_data.append(main_loop())
        _+=1

        print('Time for trial:',time()-t)
    return trial_data

def BenchmarkSim(timesteps,n_trials,unconstrained=False):
    
    def main_loop():
        
        safeDapSolver = SafeDAP(Q,R,D_x,d_x,D_u,d_u,w_max,w_cov)
        
        e_x = 0
        e_u = 0
        # Reset the environment
        env=Quadrotor1D(m,K_stab,l,w_max,dt)
        
        x_true_hist = []
        u_true_hist = []
        w_true_hist = [np.zeros((x_dim,1)) for _ in range(10*H_benchmark)]
        
        M,Phi = safeDapSolver.solve(env.A,env.B,H_benchmark,\
                                    e_x=e_x,e_u=e_u,unconstrained=unconstrained,K_stab=K_stab,b=b_target)
                
            

        # main loop 
        for _ in range(timesteps):
            
            x = env.state()
            x_true_hist.append(x)
            if _<pre_run_steps:
                u = (np.random.rand()-0.5)*2*0
            else:
                u = ApproxDAP(M,w_true_hist,0)

            env.step(u,b_target)

            u_true_hist.append(u)

            w_true_hist.append(env.state()-env.AK.dot(x_true_hist[-1])-env.B.dot(-b_target+u_true_hist[-1]))
            
            if _%100 == 0:
                print('Step',_)
            

        # Prepare data output
        data = {}
        data['x'] = x_true_hist
        data['u'] = u_true_hist
        data['w'] = w_true_hist
        data['M']  = M
        
        return data

    trial_data = []
    _ = 0 
    while _ < n_trials: 

        print('Trial {}'.format(_))
        data = main_loop()
        trial_data.append(data)
        _+=1
        
    return trial_data

# %%
alg_dict = {
    'Plain':PlainSim,
            'UnconstrainedDAP':partial(BenchmarkSim,unconstrained=True),
            'ConstrainedDAP':partial(BenchmarkSim,unconstrained=False)
           }


for key, alg in alg_dict.items():
    print("{} starts.".format(key))
    
    t = time()
      

    trial_data = alg(timesteps,n_trials)
    with open('./data/{}.pkl'.format(key),'wb') as f:
        pkl.dump(trial_data,f)
    
    print('Total Time for {}:'.format(key),time()-t)
# Out:
# Plain starts.
# Trial 0
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.012793540954589844
# Trial 1
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.011099815368652344
# Trial 2
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.011174678802490234
# Trial 3
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.012299299240112305
# Trial 4
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.010651826858520508
# Trial 5
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.010683298110961914
# Trial 6
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.010587692260742188
# Trial 7
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.011747360229492188
# Trial 8
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.01139521598815918
# Trial 9
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.013466358184814453
# Trial 10
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.010696887969970703
# Trial 11
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.010341405868530273
# Trial 12
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.011269330978393555
# Trial 13
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.01257467269897461
# Trial 14
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.011411190032958984
# Trial 15
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.010677576065063477
# Trial 16
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.012034416198730469
# Trial 17
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.01188206672668457
# Trial 18
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.011554718017578125
# Trial 19
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Time for trial: 0.012135982513427734
# Total Time for Plain: 0.29210829734802246
# UnconstrainedDAP starts.
# Trial 0
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 1
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 2
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 3
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 4
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 5
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 6
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 7
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 8
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 9
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 10
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 11
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 12
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 13
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 14
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 15
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 16
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 17
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 18
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 19
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Total Time for UnconstrainedDAP: 2.741738796234131
# ConstrainedDAP starts.
# Trial 0
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 1
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 2
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 3
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 4
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 5
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 6
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 7
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 8
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 9
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 10
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 11
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 12
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 13
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 14
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 15
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 16
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 17
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 18
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Trial 19
# Step 0
# Step 100
# Step 200
# Step 300
# Step 400
# Total Time for ConstrainedDAP: 4.562594652175903

# %% [markdown]
# # Safe Learning Experiments

# %%
est = QuadrotorEst(K_stab,dt,alpha_limit,beta_limit)
for eta_bar in eta_bars:

    def SafeAdaptiveSim(timesteps,unconstrained=False):
        # Data containers

        x_hist = []
        u_hist = []
        w_hat_hist = [np.zeros((x_dim,1)) for _ in range(10*H)]

        theta_hist = []
        refit_time_step = []
        phase1_endpoints =[]
        phase2_endpoints=[]
        M_hist = [M0]
        r_hist = []

        n_episode = 0
     
        def phase(A_hat,B_hat,old_eta,new_eta):
            # Local variables: A_hat,B_hat,old,new.
            # Global variables: theta_hist,M_hist,e_x,e_u,H,env,w_max, w_hat_hist
            # Start of the phase
            # Solve for new controller M.
            
            M,Phi = safeDapSolver.solve(A_hat,B_hat,\
                                        H,e_x = e_x,e_u = e_u,unconstrained = unconstrained,\
                                        K_stab = K_stab,b=b_target)

          
            
            if n_episode<=1:
                 old = {'M':np.array(M),'theta':(np.array(A_hat),np.array(B_hat)),'eta':old_eta,'r':r_hist[-1]}
            else:
                old = {'M':np.array(M_hist[-1]),'theta':theta_hist[-2],'eta':old_eta,'r':r_hist[-2]}
            new = {'M':np.array(M),'theta':theta_hist[-1],'eta':new_eta,'r':r_hist[-1]}

            old['e_x']=old_e_x
            new['e_x']=e_x
            
            old['e_u']=old_e_x
            new['e_u']=e_u

            M_hist.append(np.array(M))

            # Compute mid.
            mid = safeDapSolver.mid(old,new,H,K_stab)

            transit = SafeTransit(old,new,mid,H)

            for i in range(refit_per_step):
                x = env.state()
                u = transit.get_u(w_hat_hist)

                env.step(u,b_target)
    

                Ah,Bh = transit.get_theta()
                # Calculate the estimated disturbance, and project it onto the bounded disturbance set. 
             
                w_hat = env.state()-(Ah-Bh.dot(K_stab)).dot(x)-Bh.dot(-b_target+u)

                w_hat[w_hat>w_max] = w_max
                w_hat[w_hat<-w_max] = -w_max 
                w_hat_hist.append(np.array(w_hat)) 

                u_hist.append(u)
                x_hist.append(x)

                if len(x_hist)>=timesteps:
                    raise TimeStepsReached # Use the exception mechanism to stop the main loop once the total timestep is reached.

                # Updating M in the transit object.
                transit.step()
            
            # End of the phase


        env = Quadrotor1D(m,K_stab,l,w_max,dt)
      
        safeDapSolver = SafeDAP(Q,R,D_x,d_x,D_u,d_u,w_max,w_cov)
        
        # Setup the estimated parameters.
        A_hat = np.array(A_hat_0)
        B_hat = np.array(B_hat_0)
        r = r_0+0
        theta_hist.append((np.array(A_hat),np.array(B_hat)))
        r_hist.append(float(r))
        try:
            old_e_x = e_x = e_x_0
            old_e_x = e_u = e_u_0
            
            # main loop
            while True:
     
                # Phase 1: exploration exploitation 

                phase(A_hat,B_hat,0,eta_bar)

                phase1_endpoints.append(len(x_hist))

                # Refit the system model
                uh = np.array(u_hist[:-1]).reshape(-1,u_dim)
                xh = np.array(x_hist).reshape(-1,x_dim)
                A_hat,B_hat,r = est.est(xh,uh,b_target=b_target)
                
                x_t = xh[:-1,:]
                x_t_1 = xh[1:,:]
        
                   
                theta_hist.append((np.array(A_hat),np.array(B_hat)))
                r_hist.append(float(r))
                refit_time_step.append(len(x_hist))

                # Update old_e_x, old_e_u
                old_e_x = e_x+0
                old_e_u = e_u+0

                # Phase 2: pure exploitation 
                phase(A_hat,B_hat,eta_bar,0)

                phase2_endpoints.append(len(x_hist))


                print('Episode',n_episode)

                n_episode+=1
                
                old_e_x = e_x+0
                old_e_u = e_u+0
                
                print('e_x',e_x)
                e_x*=decay
                e_u*=decay

        except TimeStepsReached:
            print('Time Steps Reached')
            # Prepare data output


        # Prepare data output
        data = {}
        data['x'] = x_hist
        data['u'] = u_hist
        data['w'] = w_hat_hist
        data['theta'] = theta_hist
        data['M'] = M_hist
        return data
    
    alg_dict = {
        'SafeLearning':partial(SafeAdaptiveSim,unconstrained=False),
               'UnconstrainedLearning':partial(SafeAdaptiveSim,unconstrained=True)
               }


    for key, alg in alg_dict.items():
        print("{} starts.".format(key))
        trial_data = []
        _ = 0 
        while _ < n_trials: 
            t = time()
            try:
                print('Trial {}'.format(_))
                trial_data.append(alg(timesteps))
                _+=1
            except AttributeError:
                print('Infeasibility Encountered. Restarting the loop.')
            except cp.SolverError:
                print('Solver Error Encountered. Restarting the loop.')
            
            print('Time for trial:',time()-t)
            
        with open('./data/{}_eta_{}.pkl'.format(key,eta_bar),'wb') as f:
            pkl.dump(trial_data,f)

from IPython.display import Audio

sound_file = '../../sound/Bike-bell-sound.wav'
Audio(sound_file,autoplay=True)
# Out:
# SafeLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.115187644958496
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.1442036628723145
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.575135231018066
# Trial 3
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5793445110321045
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9298458099365234
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9433703422546387
# Trial 5
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6731789112091064
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.263158082962036
# Trial 6
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.7538943290710449
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.1469221115112305
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.632309198379517
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.0215747356414795
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.909189462661743
# Trial 10
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5561516284942627
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.969289541244507
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.961186647415161
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9848897457122803
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.0089826583862305
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.30193018913269
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.563440322875977
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.1154539585113525
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.457057476043701
# Trial 18
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6477079391479492
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.41431188583374
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.24448561668396
# UnconstrainedLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3812172412872314
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.6692874431610107
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.194706439971924
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.162611722946167
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1229970455169678
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2049412727355957
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2045705318450928
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.330075979232788
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2086236476898193
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.0996720790863037
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.071991443634033
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.235795736312866
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3435113430023193
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2521562576293945
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.45302677154541
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1671769618988037
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.192131519317627
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1378798484802246
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.5468502044677734
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.224702835083008
# SafeLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.08838415145874
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.016794919967651
# Trial 2
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5626962184906006
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.168085336685181
# Trial 3
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5898494720458984
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.113980293273926
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.08066725730896
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9219400882720947
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.8723232746124268
# Trial 7
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5683262348175049
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9646527767181396
# Trial 8
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.599931001663208
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.094503402709961
# Trial 9
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5870380401611328
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.250372648239136
# Trial 10
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5963752269744873
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.063655853271484
# Trial 11
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6619918346405029
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.337634325027466
# Trial 12
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5718331336975098
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.3317790031433105
# Trial 13
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5813741683959961
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.139329671859741
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.103679895401001
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.268357038497925
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.0257275104522705
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.13055157661438
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.2025816440582275
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.977564573287964
# UnconstrainedLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1972692012786865
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4092137813568115
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3590128421783447
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.719353199005127
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.7742934226989746
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.5802972316741943
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1914401054382324
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1445209980010986
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.159879684448242
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.248157262802124
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3157198429107666
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.7565743923187256
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4981093406677246
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4562466144561768
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.194605588912964
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1534981727600098
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2624480724334717
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.217813014984131
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3111281394958496
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2342076301574707
# SafeLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5963840484619141
# Trial 0
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5670976638793945
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.173058032989502
# Trial 1
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5823659896850586
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.221382141113281
# Trial 2
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6155099868774414
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.4222023487091064
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.418607473373413
# Trial 4
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.54933762550354
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.195576429367065
# Trial 5
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5989289283752441
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.41116189956665
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.200670480728149
# Trial 7
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6339595317840576
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.070600986480713
# Trial 8
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6028237342834473
# Trial 8
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.647728681564331
# Trial 8
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5433807373046875
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.073554515838623
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.0636491775512695
# Trial 10
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6244161128997803
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.193925380706787
# Trial 11
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6490187644958496
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.142447233200073
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.035306692123413
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.109105348587036
# Trial 14
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5836565494537354
# Trial 14
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5802381038665771
# Trial 14
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5780775547027588
# Trial 14
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5829377174377441
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9754457473754883
# Trial 15
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5561175346374512
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.129667520523071
# Trial 16
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5909543037414551
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.99877667427063
# Trial 17
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5625739097595215
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.3484086990356445
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.104094743728638
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9922754764556885
# UnconstrainedLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.29267954826355
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2779383659362793
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3804781436920166
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3162057399749756
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.342102289199829
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.314739465713501
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4927330017089844
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.20379376411438
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2779641151428223
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.187528133392334
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2107181549072266
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.329308032989502
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2083535194396973
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2973737716674805
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.303783655166626
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.305540084838867
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3344249725341797
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2373220920562744
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.137678623199463
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.1295535564422607
# SafeLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5765707492828369
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.080213308334351
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.317614793777466
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.375337362289429
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.251455068588257
# Trial 4
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5789563655853271
# Trial 4
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6446502208709717
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.22238302230835
# Trial 5
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6102275848388672
# Trial 5
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6252729892730713
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.155050992965698
# Trial 6
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5937838554382324
# Trial 6
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5943722724914551
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.039205312728882
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.036001682281494
# Trial 8
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5928473472595215
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.09617805480957
# Trial 9
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.6090075969696045
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.122705459594727
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.183758735656738
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.111857652664185
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.100486516952515
# Trial 13
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.597130537033081
# Trial 13
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5905516147613525
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.112031698226929
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.305445194244385
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.145860910415649
# Trial 16
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5732648372650146
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.9873266220092773
# Trial 17
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5656406879425049
# Trial 17
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5885217189788818
# Trial 17
# b_target -0.4325777165148185
# Infeasibility Encountered. Restarting the loop.
# Time for trial: 0.5888640880584717
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.336769342422485
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.616380453109741
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 4.294882535934448
# UnconstrainedLearning starts.
# Trial 0
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4612877368927
# Trial 1
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.628028154373169
# Trial 2
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.630990982055664
# Trial 3
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4247145652770996
# Trial 4
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.7610952854156494
# Trial 5
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.5324690341949463
# Trial 6
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.514963150024414
# Trial 7
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.6132779121398926
# Trial 8
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.8975300788879395
# Trial 9
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.4586730003356934
# Trial 10
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2909786701202393
# Trial 11
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2900097370147705
# Trial 12
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.593346118927002
# Trial 13
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.624363899230957
# Trial 14
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.348191499710083
# Trial 15
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.560473680496216
# Trial 16
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.3036797046661377
# Trial 17
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2354650497436523
# Trial 18
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.307979106903076
# Trial 19
# b_target -0.4325777165148185
# Episode 0
# e_x 1.0
# b_target -0.4325777165148185
# Episode 1
# e_x 0.7
# b_target -0.4325777165148185
# Episode 2
# e_x 0.48999999999999994
# b_target -0.4325777165148185
# Episode 3
# e_x 0.3429999999999999
# b_target -0.4325777165148185
# Time Steps Reached
# Time for trial: 3.2262279987335205
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
